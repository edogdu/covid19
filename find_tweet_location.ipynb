# %%
import json

# %%
fhand = open('coronavirus-tweet-id-2020-05-01-00.jsonl')

# %%
for line in fhand:
    tweet = json.loads(line)
    try:
        geo = tweet['coordinates']
        if geo != None:
            print(geo)
        print(tweet['place']['name'],tweet['place']['country'])
    except:
        continue
# Out:
# Fukuyama-shi Japan
# Limoges France
# Centre Cameroon
# Bahamas Bahamas
# Iraq Iraq
# Imizu-shi Japan
# Nova Iguaçu Brazil
# Staten Island United States
# {'type': 'Point', 'coordinates': [107.7294, -6.9365]}
# Cileunyi Indonesia
# Idaho United States
# Mackay Australia
# Ikeja Nigeria
# Salt Lake City United States
# Gifu-shi Japan
# Oslo Beach South Africa
# Itapiranga Brazil
# Niger Nigeria
# {'type': 'Point', 'coordinates': [139.983, 35.8667]}
# Kashiwa-shi Japan
# Québec Canada
# Suzano Brazil
# Evry France
# Sao Paulo Brazil
# Lanark Highlands Canada
# La Florida Chile
# Lagos Nigeria
# Curug Indonesia
# Brussels Belgium
# São Bernardo do Campo Brazil
# Boston United States
# Sao Paulo Brazil
# Nicaragua Nicaragua
# Washington United States
# Crystal City United States
# Belo Horizonte Brazil
# Suzaka-shi Japan
# Antelope United States
# West Virginia United States
# Maldives Maldives
# Scottsdale United States
# Brewster United States
# Anaheim United States
# ...
