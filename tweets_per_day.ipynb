# %%
import json
import os,glob

# %%
folder_path = 'D:\\COVID-19-TweetIDs\\2020-01\\New folder\\22'

# %%
total_per_day = []
date = []
for filename in glob.glob(os.path.join(folder_path, '*.jsonl')):
    fhand = open(filename, 'r',encoding="utf8")
    text = fhand.readlines()
    print (filename)
    print(len(text))
    date.append(filename[70:74])

# %%
date = list( dict.fromkeys(date) )
print(date)

# %%
for a in range(len(date)):
    total= 0
    for filename in glob.glob(os.path.join(folder_path, '*.jsonl')):
        fhand = open(filename, 'r',encoding="utf8")
        text = fhand.readlines()
        if date[a] in filename:
            total += len(text)
    total_per_day.append(total)

# %%
print(total_per_day)
# Out:
# [180, 573]

# %%
tweets_per_day = {date[i]: total_per_day[i] for i in range(len(date))}

# %%
print(tweets_per_day)
# Out:
# {'1-21': 180, '1-22': 573}

# %%
for filename in glob.glob(os.path.join(folder_path, '*.jsonl')):
    fhand = open(filename, 'r',encoding="utf8")
    for line in fhand:
        tweet = json.loads(line)
        try:
            print(tweet['user']['location'])
        except:
            continue
# Out:
# 21.047051,-86.881061
# Washington, D.C.
# +63
#   🌳🇺🇸Tree of Liberty , USA 🌳🇺🇸
# Atlanta, GA
# Oxnard, CA
# Parkville, MO
# Japan
# Navi Mumbai ↔ Pune
# Italy
# Chicago, IL
# Minneapolis
# Newport, KY
#
#
# Chicago, IL
# Windhoek-Paris-Yaoundé
# Texas, USA
# USA
# 🌎of Mystery
# warnsomegraphicphotosbadnews
#
# Boulder, Seattle, LA, Oregon
# Inside The Loop
#
#
#
# PA
#
# Durham, NC
# Illinois, USA
# Arkansas, USA
# United States
# usa
# Pequeño Punto Azul 🌎
# Alabama
#
# Canada
# United States
# Winnipeg, Manitoba
# Culiacán, Sinaloa
#
# MIA ❊
# North Dakota, USA
# Manchester
#
#
# Toronto
# Johnson City, TN
# Portland, OR
# North Carolina
#
# Birmingham, AL
# United States Of America
# CO-MT-ND-SD-UT-WY
# Rocky Ford, CO
# Tokyo
# Maryland, USA
#
# Memphis, TN
#
# Los Alamitos, Ca
# Indianapolis, IN
#
# Ontario
# Turku, Finland
# Montana
#
# CA
#
# Blocksburg, Ca
#
#
# Mid West
#
# Atlanta, GA
# United States Of America
#
#  MEL (via US) rtw ≠ endorse
# Loja,Ecuador
# United States of America
# Washington, DC
#
# Virginia
# Florida
#
# Madrid
# Georgia, USA
# Bedfordshire
#
# Puerto Rico
# Kentucky, USA
# SKYFORGE
#
#
# MO
#
#
# Canada
#
# USA
# Ontario, Canada
#
# In the Middle
# Florida, USA
# International
# MISSISSIPPI 🇺🇸
# Texas, USA
#
#
# ⚡️
# Aracaju, Brasil
# West Caldwell, NJ
# Las Vegas, NV
